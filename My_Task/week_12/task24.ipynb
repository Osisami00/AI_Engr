# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Ingection

# %%
#ingesting test data for EDA

df_test = pd.read_csv("loan-test.csv")
df_test.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
#ingesting train data for EDA

df_train = pd.read_csv("loan-train.csv")
df_train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
# Checking data shape before joining train and test dataset together
df_train.shape
# Out:
# (614, 13)

# %%
df_test.shape
# Out:
# (367, 12)

# %% [markdown]
# ## Preliminary Data Analysis

# %%
# Data Concatenation for adequate EDA

df = pd.concat([df_test,df_train],axis=0,ignore_index=True)
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                0.0       110.0             360.0
# 1             3076             1500.0       126.0             360.0
# 2             5000             1800.0       208.0             360.0
# 3             2340             2546.0       100.0             360.0
# 4             3276                0.0        78.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban         NaN
# 1             1.0         Urban         NaN
# ...

# %% [markdown]
# ## Preliminary Data Analysis

# %%
# Checking the shape of the new joined dataset
df.shape
# Out:
# (981, 13)

# %%
# chcking the tail of the new dataset to see if the index number is aligned
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 976  LP002978  Female      No          0  Graduate            No
# 977  LP002979    Male     Yes         3+  Graduate            No
# 978  LP002983    Male     Yes          1  Graduate            No
# 979  LP002984    Male     Yes          2  Graduate            No
# 980  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 976             2900                0.0        71.0             360.0
# 977             4106                0.0        40.0             180.0
# 978             8072              240.0       253.0             360.0
# 979             7583                0.0       187.0             360.0
# 980             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 976             1.0         Rural           Y
# 977             1.0         Rural           Y
# ...

# %%
# checking the column names of the dataset

df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
# checking information about each column in the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 981 entries, 0 to 980
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            981 non-null    object
#  1   Gender             957 non-null    object
#  2   Married            978 non-null    object
#  3   Dependents         956 non-null    object
#  4   Education          981 non-null    object
#  5   Self_Employed      926 non-null    object
#  6   ApplicantIncome    981 non-null    int64
#  7   CoapplicantIncome  981 non-null    float64
#  8   LoanAmount         954 non-null    float64
#  9   Loan_Amount_Term   961 non-null    float64
#  10  Credit_History     902 non-null    float64
#  11  Property_Area      981 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 99.8+ KB

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       981.000000         981.000000  954.000000        961.000000
# mean       5179.795107        1601.916330  142.511530        342.201873
# std        5695.104533        2718.772806   77.421743         65.100602
# min           0.000000           0.000000    9.000000          6.000000
# 25%        2875.000000           0.000000  100.000000        360.000000
# 50%        3800.000000        1110.000000  126.000000        360.000000
# 75%        5516.000000        2365.000000  162.000000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History
# count      902.000000
# mean         0.835920
# std          0.370553
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# Data Cleaning

# %%
# checking the number missing data per columns 

df.isna().sum()
# Out:
# Loan_ID                0
# Gender                24
# Married                3
# Dependents            25
# Education              0
# Self_Employed         55
# ApplicantIncome        0
# CoapplicantIncome      0
# LoanAmount            27
# Loan_Amount_Term      20
# Credit_History        79
# Property_Area          0
# Loan_Status          367
# dtype: int64

# %% [markdown]
# Handling columns with missing data

# %%
# For Loan_Status: 
# 1- it has 367missing data and it is too 
# 2- it is much to guess such a wide range of missing dat 
# 3- Also filling the data with anything like mean or mode might have a huge impact
# of bias
# 4- The best thing to do is to drop the rows with the missing rows
# This will reduce the length of th dataset but prevent our data from bias 


# Dropping rows with missing column
df1 = df.copy()
df = df.dropna(subset=["Loan_Status"])
# df.head()

# %%
df1.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                0.0       110.0             360.0
# 1             3076             1500.0       126.0             360.0
# 2             5000             1800.0       208.0             360.0
# 3             2340             2546.0       100.0             360.0
# 4             3276                0.0        78.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban         NaN
# 1             1.0         Urban         NaN
# ...

# %%
df["Loan_Status"].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Handling gender missing column

# %%
df.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['Gender'].value_counts(dropna=False)
# Out:
# Gender
# Male      489
# Female    112
# NaN        13
# Name: count, dtype: int64

# %%
# Let drop Gender rows with missing data
