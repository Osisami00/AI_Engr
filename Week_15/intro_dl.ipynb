# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification

# %%
class Perceptron:
    def __init__(self, num_features):
        self.num_features = num_features
        self.weights = [0.0 for _ in range(num_features)]
        self.bias = 0

    def forward(self, x):
        weighted_sum_z = self.bias
        for i, _ in enumerate(self.weights):
            weighted_sum_z += x[i] * self.weights[i]

        if weighted_sum_z > 0:
            prediction = 1
        else:
            prediction = 0

        return prediction
    

ppn = Perceptron(num_features = 2) # Re-initialize with 2 features
x = [1.23, 2.13]
ppn.forward(x)
# Out:
# 0

# %%
print("Model parameters:")
print("Weights:", ppn.weights)
print("Bias:", ppn.bias)
# Out:
# Model parameters:
# Weights: [0.0, 0.0]
# Bias: 0

# %%
class Perceptron:
    def __init__(self, num_features):
        self.num_features = num_features
        self.weights = [0.0 for _ in range(num_features)]
        self.bias = 0

    def forward(self, x):
        weighted_sum_z = self.bias
        for i, _ in enumerate(self.weights):
            weighted_sum_z += x[i] * self.weights[i]

        if weighted_sum_z > 0:
            prediction = 1
        else:
            prediction = 0

        return prediction


ppn = Perceptron(num_features = 2)
x = [1.1, 2.1]
ppn.forward(x, y_true = 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 22
#      20 ppn = Perceptron(num_features = 2)
#      21 x = [1.1, 2.1]
# ---> 22 ppn.forward(x, y_true = 1)
#
# TypeError: Perceptron.forward() got an unexpected keyword argument 'y_true'
